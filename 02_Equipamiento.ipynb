# %% [markdown]
# # Análisis de Equipamiento desde Fondequip
# ## Datos entregados por el Mineduc en Chile
# * Ejecutado en mi entorno conda Stats
# * Autor: Alexis Salas Burgos
# * Fecha: Septiembre 2020

# %%
# importando bibliotecas requerido en python
import pandas as pd
import altair as alt
import seaborn as sns

# %%
df = pd.read_excel("data/Fondequip_equipos.xlsx", skiprows=5)
df
# Out:
#          Folio   Programa                               Institución  \
# 0    EQM190179  FONDEQUIP                 UNIVERSIDAD DE VALPARAISO
# 1    EQM190177  FONDEQUIP                      UNIVERSIDAD DE CHILE
# 2    EQM190162  FONDEQUIP  PONTIFICIA UNIVERSIDAD CATOLICA DE CHILE
# 3    EQM190153  FONDEQUIP                      UNIVERSIDAD DE TALCA
# 4    EQM190142  FONDEQUIP              UNIVERSIDAD AUSTRAL DE CHILE
# ..         ...        ...                                       ...
# 306  EQM120021  FONDEQUIP  PONTIFICIA UNIVERSIDAD CATOLICA DE CHILE
# 307  EQM120008  FONDEQUIP                      UNIVERSIDAD DE TALCA
# 308  EQM120005  FONDEQUIP                UNIVERSIDAD DE ANTOFAGASTA
# 309  EQM120003  FONDEQUIP                      UNIVERSIDAD DE CHILE
# 310        NaN        NaN                                       NaN
#
#     Región Instalación del Equipo            Tipo de Equipamiento  \
# 0            Región de Valparaíso                           Otros
# 1            Región Metropolitana                           Otros
# 2            Región Metropolitana                           Otros
# 3                Región del Maule                           Otros
# 4              Región de Los Ríos                           Otros
# ..                            ...                             ...
# 306          Región Metropolitana  Cromatógrafos y Espectrómetros
# 307              Región del Maule  Cromatógrafos y Espectrómetros
# 308         Región de Antofagasta  Cromatógrafos y Espectrómetros
# 309          Región Metropolitana   Microscopios y Difractómetros
# 310                           NaN               Secuenciación ADN
#
#     Tipo de Equipamiento 2    Área OECD  \
# 0                      NaN          NaN
# 1                      NaN          NaN
# 2                      NaN          NaN
# 3      Sensores Organismos  Biomedicina
# 4                      NaN          NaN
# ..                     ...          ...
# 306                    NaN          NaN
# 307           Cromátografo          NaN
# 308                    NaN          NaN
# 309                    NaN          NaN
# 310       Secuenciador ADN          NaN
#
#                                                 Equipo  \
# 0    MICROSCOPIO ELECTRÓNICO DE BARRIDO DE EMISIÓN ...
# 1                     MICROSCOPIA DE BARRIDO POR SONDA
# 2                                  GONIO-PHOTOMETER G2
# 3    DISPOSITIVO INTEGRADO NOLDUS DE OBSERVACIÓN DE...
# 4                                      Q-EXACTIVE PLUS
# ..                                                 ...
# 306                            ESPECTÓMETRO RMN 200MHZ
# 307  CROMATOGRAFO DE GASES CON DETECTOR DE MASAS GC-MS
# 308  SISTEMA INTEGRADO DE CARACTERIZACIÓN DE PARTÍC...
# 309                     MICROSCOPIO CONFOCAL ESPECTRAL
# 310                                     Illumina Miseq
#
#                         Marca                         Modelo  \
# 0                  Carl Zeiss               Sigma 300 Gemini
# 1                      BRUKER             SPM DIMENSION ICON
# 2                         pab                             G2
# 3                      NOLDUS  NOLDUS INFORMATION TECHNOLOGY
# 4                      Thermo                Q-Exactive plus
# ..                        ...                            ...
# 306                    Bruker                 Avance III 200
# 307  Thermo Fisher Scientific                  Trace GC 1310
# 308            Mettler Toledo             FBRM-G400 PVM-V819
# 309                     Zeiss                         LSM710
# 310                       NaN                            NaN
#
#     Coordinador Responsable                           Email
# 0            Rodrigo Segura            rodrigo.segura@uv.cl
# 1          Isadora Berlanga  isadora.berlanga@ing.uchile.cl
# 2               Sergio Vera                svera@ing.puc.cl
# 3            RAMON CASTILLO            racastillo@utalca.cl
# 4            Carlos Alvarez            calvarezbq@gmail.com
# ..                      ...                             ...
# 306         Mauricio Isaacs                   misaacs@uc.cl
# 307          Luis Astudillo               lastudi@utalca.cl
# 308          Teófilo Graber               tgraber@uantof.cl
# 309      Christian Gonzalez              chrgonza@uchile.cl
# 310       Cristian Gallardo                             NaN
#
# [311 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Folio', 'Programa', 'Institución', 'Región Instalación del Equipo',
#        'Tipo de Equipamiento', 'Equipo', 'Marca', 'Modelo',
#        'Coordinador Responsable', 'Email'],
#       dtype='object')

# %%
df['Región Instalación del Equipo'].unique()
# Out:
# array(['Región de Valparaíso', 'Región Metropolitana', 'Región del Maule',
#        'Región de Los Ríos', 'Región de Tarapacá',
#        'Región de Magallanes y la Antártica Chilena',
#        'Región del Bío-Bío', 'Región de la Araucanía',
#        'Región de los Lagos', 'Región de Antofagasta',
#        'Región Aysén del General Carlos Ibáñez del Campo',
#        'Región de Coquimbo', 'Región de Atacama', 'Región Ñuble'],
#       dtype=object)

# %%
import altair as alt
alt.data_transformers.disable_max_rows()

alt.Chart(df).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y=alt.Y('count(Región Instalación del Equipo):Q', stack=True),
    x='Región Instalación del Equipo:O',
    #color='GEN_ALU:N',
    #column='REGION_SEDE:O'
    
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
alt.data_transformers.disable_max_rows()

alt.Chart(df).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y=alt.Y('count(Institución):Q', stack=True),
    x='Institución:O',
    #color='GEN_ALU:N',
    #column='REGION_SEDE:O'
    
)
# Out:
# alt.Chart(...)

# %%
# Macrozona
df["Región"] = df['Región Instalación del Equipo']
data = df.query("Región in ['Región del Bío-Bío','Región Ñuble','Región del Maule']")
print(data.shape)
data.head(3)
# Out:
# (55, 13)
#         Folio   Programa                Institución  \
# 3   EQM190153  FONDEQUIP       UNIVERSIDAD DE TALCA
# 7   EQM190124  FONDEQUIP       UNIVERSIDAD DE TALCA
# 28  EQM190002  FONDEQUIP  UNIVERSIDAD DE CONCEPCION
#
#    Región Instalación del Equipo Tipo de Equipamiento  \
# 3               Región del Maule                Otros
# 7               Región del Maule                Otros
# 28            Región del Bío-Bío                Otros
#
#           Tipo de Equipamiento 2      Área OECD  \
# 3            Sensores Organismos    Biomedicina
# 7   Sensores Laboratorio Natural          Clima
# 28       Análisis de Materiales   Industria 4.0
#
#                                                Equipo                Marca  \
# 3   DISPOSITIVO INTEGRADO NOLDUS DE OBSERVACIÓN DE...               NOLDUS
# 7   PLATAFORMA DE FENOTIPEO AÉREA CON CÁMARA HIPER...  Headwall Photonics
# 28                                NANOTRIBOINDENTADOR               Bruker
#
#                                                Modelo Coordinador Responsable  \
# 3                       NOLDUS INFORMATION TECHNOLOGY          RAMON CASTILLO
# 7   Co-Aligned hyperspectral sensor 400-2500nm wit...           Gustavo Lobos
# 28                                    Hysitron TI 980        manuel melendrez
#
#                    Email              Región
# 3   racastillo@utalca.cl    Región del Maule
# 7      globosp@utalca.cl    Región del Maule
# 28    mmelendrez@udec.cl  Región del Bío-Bío

# %%
import altair as alt
alt.data_transformers.disable_max_rows()

chart = alt.Chart(data).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y=alt.Y('count(Tipo de Equipamiento):Q', stack=True),
    x='Tipo de Equipamiento:O',
    color=alt.Color('Institución:N', scale=alt.Scale(scheme='set1')),
    column='Región:O'
    
).properties(
    title='Tipo de Instrumento en la Macrozona Centro Sur (Fondequip 2012-2019)',
    
    width=250
)

chart.configure_title(
    fontSize=24,
    font='Courier',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)

# %%
import altair as alt
alt.data_transformers.disable_max_rows()

chart = alt.Chart(data).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y=alt.Y('count(Tipo de Equipamiento 2):Q', stack=True),
    x='Tipo de Equipamiento 2:O',
    color=alt.Color('Institución:N', scale=alt.Scale(scheme='set1')),
    column='Región:O'
    
).properties(
    title='Tipo de Instrumento en la Macrozona Centro Sur (Fondequip 2012-2019)',
     
    width=250
)

chart.configure_title(
    fontSize=24,
    font='Courier',
    anchor='middle',
    color='black'
)
# Out:
# alt.Chart(...)
