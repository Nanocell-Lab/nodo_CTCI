# %% [markdown]
# # Análisis de Investigación Macrozona Sur
# ## Datos desde CNED Chile
# * Ejecutado en mi entorno conda Stats
# * Autor: Alexis Salas Burgos
# * Fecha: Septiembre 2020

# %%
# importando bibliotecas requerido en python
import pandas as pd
import altair as alt
import seaborn as sns
import json

# %%
df = pd.read_csv("data/DataCiencia_disciplinas_data.csv", sep=',', skiprows=0)

# %%
df = pd.read_csv("data/DataCiencia_disciplinas_data.csv", sep=',', skiprows=0)
df.rename(columns={"CATEGORÍA":"Disciplina WoS"})
# process json-like elemnts and NaN values for each column
for n in df.columns[1:]:
    col_isna = df[n].isna()
    # convert json-like string elements to json object
    col_tojson = df.loc[-col_isna,n].str.replace("\'","\"").apply(json.loads)
    # extract value from json object
    df.loc[-col_isna,n] = col_tojson.apply(lambda item: item["times"])
    # nan elements to default zero
    df.loc[col_isna,n] = 0

# %%
pd_long = df.melt(id_vars=["CATEGORÍA"],var_name="Disciplina OECD",value_name="Cantidad")
pd_long
# Out:
#                                 CATEGORÍA        Disciplina OECD Cantidad
# 0                               ACOUSTICS  AGRICULTURAL SCIENCES        0
# 1         AGRICULTURAL ECONOMICS & POLICY  AGRICULTURAL SCIENCES       13
# 2                AGRICULTURAL ENGINEERING  AGRICULTURAL SCIENCES       41
# 3     AGRICULTURE, DAIRY & ANIMAL SCIENCE  AGRICULTURAL SCIENCES       18
# 4          AGRICULTURE, MULTIDISCIPLINARY  AGRICULTURAL SCIENCES      100
# ...                                   ...                    ...      ...
# 1423                  VETERINARY SCIENCES             HUMANITIES        0
# 1424                             VIROLOGY             HUMANITIES        0
# 1425                      WATER RESOURCES             HUMANITIES        0
# 1426                       WOMENS STUDIES             HUMANITIES        0
# 1427                              ZOOLOGY             HUMANITIES        0
#
# [1428 rows x 3 columns]

# %%
# import altair as alt
# alt.data_transformers.disable_max_rows()

# alt.Chart(df_log).mark_bar(
#     cornerRadiusTopLeft=3,
#     cornerRadiusTopRight=3
# ).encode(
#     y=alt.Y('sum(OECD_AREA):Q', stack=True),
#     x='OECD_AREA:O',
#     color='GEN_ALU:N',
#     column='REGION_SEDE:O'
    
# )

# %% [markdown]
# # Plots Data Reportes
#
# ### Datos concatenads al scrapear individualmente por año.

# %%
datos_region = pd.read_csv("data/DataCiencia_reporteRegion_sur.v2.csv",index_col=0)
datos_oecd = pd.read_csv("data/DataCiencia_reporteOECD_sur.v2.csv",index_col=0)
datos_wos = pd.read_csv("data/DataCiencia_reporteWoS_sur.v2.csv",index_col=0)
datos_inst = pd.read_csv("data/DataCiencia_reporteInst_sur.v2.csv",index_col=0)

# %%
# datos_region["max_sexo"] = 100

# sexo1 = alt.Chart(datos_region).mark_bar(
# ).encode(
#     y2 = alt.Y2('max_sexo:Q',title="Porcentaje"),
#     y = alt.Y('% Mujer:Q',title=""),
#     x='año:O',
#     color=alt.value('blue'),
#     #column='Nombre Región:N'
    
# )

# sexo2 = alt.Chart(datos_region).mark_bar(
# ).encode(
#     y = alt.Y('% Mujer:Q',title=""),
#     x='año:O',
#     color=alt.value('red'),
#     #column='Nombre Región:N'
    
# )
# final1= (sexo1+sexo2).properties( width=200,
#     height=200).facet(alt.Facet('region:N', title="Publicaciones en Regiónes por Sexo")).resolve_scale(
#   x='independent'
# )
# final1
# final1.save("Pub_sexo_regiones.svg",scale_factor=1.0)
# Out:
# alt.FacetChart(...)

# %%
# Out:
# 11

# %%
# produccion per capita
datos_region.loc[datos_region['año']!=2020].groupby(['Región'])['Producción Per Cápita'].describe()
# Out:
#                                                   count      mean       std  \
# Región
# Región de Ñuble                                    12.0  0.750000  0.108711
# Región del Biobío                                  12.0  0.791667  0.051493
# Región del Libertador General Bernardo O'Higgins   12.0  0.833333  0.205971
# Región del Maule                                   12.0  0.833333  0.098473
#
#                                                   min    25%   50%   75%  max
# Región
# Región de Ñuble                                   0.6  0.700  0.75  0.80  1.0
# Región del Biobío                                 0.7  0.800  0.80  0.80  0.9
# Región del Libertador General Bernardo O'Higgins  0.5  0.675  0.85  0.95  1.1
# Región del Maule                                  0.7  0.775  0.85  0.90  1.0

# %%
#alt.data_transformers.disable_max_rows()

alt.Chart(datos_region.loc[datos_region['año']!=2020]).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y = alt.Y('# Publicaciones:Q'),
    x='año:O',
    color='region:N',
    #column='Nombre Región:N'
    
).properties( width=200,
    height=200).facet(facet='region:O', columns=2,center=True).resolve_scale(
  x='independent'
)
# Out:
# alt.FacetChart(...)

# %%
alt.Chart(datos_region.loc[datos_region['año']!=2020]).mark_line(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y = alt.Y('Producción Per Cápita:Q'),
    x='año:O',
    color='region:N',
    #column='Nombre Región:N'
    
).properties( width=700,
    height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### OECD pulicaciones

# %%
datos_oecd["% Mujer"] = datos_oecd["% Mujer"].str.strip("%").copy().astype(int)
datos_oecd["% Hombre"] = datos_oecd["% Hombre"].str.strip("%").copy().astype(int)

datos_oecd["max_sexo"] = 100

# %%
datos_oecd.loc[datos_oecd['año']!=2020].groupby(["Disciplina","region",'año'])['# Publicaciones'].describe()
# Out:
#                                    count  mean  std   min   25%   50%   75%  \
# Disciplina            region año
# AGRICULTURAL SCIENCES Biobío 2008    1.0  33.0  NaN  33.0  33.0  33.0  33.0
#                              2009    1.0  68.0  NaN  68.0  68.0  68.0  68.0
#                              2010    1.0  71.0  NaN  71.0  71.0  71.0  71.0
#                              2011    1.0  61.0  NaN  61.0  61.0  61.0  61.0
#                              2012    1.0  77.0  NaN  77.0  77.0  77.0  77.0
# ...                                  ...   ...  ...   ...   ...   ...   ...
# SOCIAL SCIENCES       Ñuble  2015    1.0   4.0  NaN   4.0   4.0   4.0   4.0
#                              2016    1.0   3.0  NaN   3.0   3.0   3.0   3.0
#                              2017    1.0   3.0  NaN   3.0   3.0   3.0   3.0
#                              2018    1.0   8.0  NaN   8.0   8.0   8.0   8.0
#                              2019    1.0  11.0  NaN  11.0  11.0  11.0  11.0
#
#                                     max
# Disciplina            region año
# AGRICULTURAL SCIENCES Biobío 2008  33.0
#                              2009  68.0
#                              2010  71.0
#                              2011  61.0
#                              2012  77.0
# ...                                 ...
# SOCIAL SCIENCES       Ñuble  2015   4.0
#                              2016   3.0
#                              2017   3.0
#                              2018   8.0
#                              2019  11.0
#
# [267 rows x 8 columns]

# %%
datos_oecd_aggmean = datos_oecd.loc[datos_oecd['año']!=2020].groupby(["Disciplina","region"]).mean().reset_index()
datos_oecd_aggmean.head()
# Out:
#                    Disciplina     region  # Publicaciones   # Autores  \
# 0       AGRICULTURAL SCIENCES     Biobío        86.500000  169.583333
# 1       AGRICULTURAL SCIENCES      Maule        51.833333   90.416667
# 2       AGRICULTURAL SCIENCES  O'Higgins         6.250000    8.500000
# 3       AGRICULTURAL SCIENCES      Ñuble        49.833333  101.666667
# 4  ENGINEERING AND TECHNOLOGY     Biobío       233.083333  365.916667
#
#     % Hombre    % Mujer  Producción Per Cápita     año  max_sexo
# 0  65.166667  34.833333               0.508333  2013.5     100.0
# 1  71.916667  28.083333               0.583333  2013.5     100.0
# 2  85.000000  15.000000               0.933333  2013.5     100.0
# 3  66.500000  33.500000               0.508333  2013.5     100.0
# 4  74.000000  26.000000               0.641667  2013.5     100.0

# %% [markdown]
# ### Descripcion por sexo

# %%
datos_oecd_aggmean["Pub. Mujer"] = round(((datos_oecd_aggmean["% Mujer"]/100)*datos_oecd_aggmean["# Publicaciones"]))
datos_oecd_aggmean["Pub. Hombre"] = round(((datos_oecd_aggmean["% Hombre"]/100)*datos_oecd_aggmean["# Publicaciones"]))

# %%
datos_oecd_aggmean.head()
# Out:
#                    Disciplina     region  # Publicaciones   # Autores  \
# 0       AGRICULTURAL SCIENCES     Biobío        86.500000  169.583333
# 1       AGRICULTURAL SCIENCES      Maule        51.833333   90.416667
# 2       AGRICULTURAL SCIENCES  O'Higgins         6.250000    8.500000
# 3       AGRICULTURAL SCIENCES      Ñuble        49.833333  101.666667
# 4  ENGINEERING AND TECHNOLOGY     Biobío       233.083333  365.916667
#
#     % Hombre    % Mujer  Producción Per Cápita     año  max_sexo  Pub. Mujer  \
# 0  65.166667  34.833333               0.508333  2013.5     100.0        30.0
# 1  71.916667  28.083333               0.583333  2013.5     100.0        15.0
# 2  85.000000  15.000000               0.933333  2013.5     100.0         1.0
# 3  66.500000  33.500000               0.508333  2013.5     100.0        17.0
# 4  74.000000  26.000000               0.641667  2013.5     100.0        61.0
#
#    Pub. Hombre
# 0         56.0
# 1         37.0
# 2          5.0
# 3         33.0
# 4        172.0

# %%
datos_oecd_pubsexo = pd.melt(datos_oecd_aggmean,id_vars=['Disciplina','region'], value_vars = ['Pub. Mujer','Pub. Hombre'],
                             value_name="Publicaciones",var_name="Sexo")
datos_oecd_pubsexo.head()
# Out:
#                    Disciplina     region        Sexo  Publicaciones
# 0       AGRICULTURAL SCIENCES     Biobío  Pub. Mujer           30.0
# 1       AGRICULTURAL SCIENCES      Maule  Pub. Mujer           15.0
# 2       AGRICULTURAL SCIENCES  O'Higgins  Pub. Mujer            1.0
# 3       AGRICULTURAL SCIENCES      Ñuble  Pub. Mujer           17.0
# 4  ENGINEERING AND TECHNOLOGY     Biobío  Pub. Mujer           61.0

# %%
pubsexo = alt.Chart(datos_oecd_pubsexo).mark_bar(
).encode(
    y = alt.Y('Publicaciones:Q',title="Publicaciones"),
    x=alt.X('region:O',title="Región"),
    color=alt.Color('Sexo',title=""),
    #column=alt.Column('Disciplina:O'),
    ).properties( width=150,
    height=150).facet(alt.Facet('Disciplina:O',title=""), columns=3,center=True).resolve_scale(
  y='independent'
)
pubsexo
#pubsexo.save("pubsexo_oecd.png",scale_factor=2.0)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ### produccion per capita

# %%
alt.Chart(datos_oecd_aggmean).mark_bar(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y = alt.Y('Producción Per Cápita:Q'),
    x=alt.X('region:O',title="Región",),
    color='Disciplina:N',
    #column='Disciplina:N'
    
).properties( width=100,
    height=200).facet(alt.Facet('Disciplina:O',title=""), columns=3,center=True)
# Out:
# alt.FacetChart(...)

# %%
# sexo1 = alt.Chart(datos_oecd).mark_bar(
# ).encode(
#     y2 = alt.Y2('max_sexo:Q',title="Porcentaje"),
#     y = alt.Y('% Mujer:Q',title=""),
#     x='año:O',
#     color=alt.value('blue'),
#     #column='Nombre Región:N'
    
# )

# sexo2 = alt.Chart(datos_oecd).mark_bar(
# ).encode(
#     y = alt.Y('% Mujer:Q',title=""),
#     x='año:O',
#     color=alt.value('red'),
#     #column='Nombre Región:N'
    
# )
# final1= (sexo1+sexo2).properties( width=200,
#     height=200).facet(alt.Facet('Disciplina:N', title="Publicaciones Disciplinas OECD por Sexo"),columns=3).resolve_scale(
#   x='independent'
# )
# final1

# %%
alt.Chart(datos_oecd).mark_line(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y = alt.Y('# Publicaciones:Q'),
    x='año:O',
    color='Disciplina:N',
    #column='Nombre Región:N'
    
).properties( width=700,
    height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Publicaciones WoS

# %%
# mapping OECD WoS
oecd_wos_mapping = pd.read_table("oecd_wos_mapping.txt",names=["OECD","CODE","WoS"])
oecd_wos_mapping = oecd_wos_mapping[["OECD","WoS"]]

oecd_wos_dict = {n:g["OECD"].tolist()[0] for n,g in oecd_wos_mapping.groupby("WoS")}
datos_wos["OECD"] = datos_wos["Disciplina"].map(oecd_wos_dict)

# %%
habitantes = {"Biobío":1556805,"Ñuble":480609,"Maule":1044950,"O'Higgins":914555}

# %%
datos_wos_aggmean = datos_wos.loc[datos_wos['año']!=2020].groupby(["Disciplina","region","OECD"]).mean().reset_index()

# %%
datos_wos_aggmean["Pub/100mil"] = datos_wos_aggmean["# Publicaciones"]/datos_wos_aggmean["region"].map(habitantes)*100000

# %% [markdown]
# ### Descripcion por region

# %%
biobio_disc = set(datos_wos_aggmean.loc[datos_wos_aggmean['region']=='Biobío']['Disciplina'])
wos_disc = set(oecd_wos_mapping["WoS"].tolist())
len(wos_disc)
# Out:
# 251

# %%
# Bio Bio
datos_wos_aggmean.loc[datos_wos_aggmean['region']=='Biobío'].groupby(['Disciplina','region','OECD'])['Pub/100mil'].describe().sort_values(by='mean',ascending=False)
# Out:
#                                                                          count  \
# Disciplina                           region OECD
# ASTRONOMY & ASTROPHYSICS             Biobío NATURAL SCIENCES               1.0
# MARINE & FRESHWATER BIOLOGY          Biobío NATURAL SCIENCES               1.0
# MATHEMATICS                          Biobío NATURAL SCIENCES               1.0
# ENVIRONMENTAL SCIENCES               Biobío NATURAL SCIENCES               1.0
# ENGINEERING, ELECTRICAL & ELECTRONIC Biobío ENGINEERING AND TECHNOLOGY     1.0
# ...                                                                        ...
# ENGINEERING, MARINE                  Biobío ENGINEERING AND TECHNOLOGY     1.0
# ETHNIC STUDIES                       Biobío SOCIAL SCIENCES                1.0
# SOCIAL ISSUES                        Biobío SOCIAL SCIENCES                1.0
# PRIMARY HEALTH CARE                  Biobío MEDICAL AND HEALTH SCIENCES    1.0
# PSYCHOLOGY, BIOLOGICAL               Biobío SOCIAL SCIENCES                1.0
#
#                                                                              mean  \
# Disciplina                           region OECD
# ASTRONOMY & ASTROPHYSICS             Biobío NATURAL SCIENCES             7.188869
# MARINE & FRESHWATER BIOLOGY          Biobío NATURAL SCIENCES             4.367920
# MATHEMATICS                          Biobío NATURAL SCIENCES             3.966457
# ENVIRONMENTAL SCIENCES               Biobío NATURAL SCIENCES             3.506112
# ENGINEERING, ELECTRICAL & ELECTRONIC Biobío ENGINEERING AND TECHNOLOGY   3.425820
# ...                                                                           ...
# ENGINEERING, MARINE                  Biobío ENGINEERING AND TECHNOLOGY   0.064234
# ETHNIC STUDIES                       Biobío SOCIAL SCIENCES              0.064234
# SOCIAL ISSUES                        Biobío SOCIAL SCIENCES              0.064234
# PRIMARY HEALTH CARE                  Biobío MEDICAL AND HEALTH SCIENCES  0.064234
# PSYCHOLOGY, BIOLOGICAL               Biobío SOCIAL SCIENCES              0.064234
#
#                                                                          std  \
# Disciplina                           region OECD
# ASTRONOMY & ASTROPHYSICS             Biobío NATURAL SCIENCES             NaN
# MARINE & FRESHWATER BIOLOGY          Biobío NATURAL SCIENCES             NaN
# MATHEMATICS                          Biobío NATURAL SCIENCES             NaN
# ENVIRONMENTAL SCIENCES               Biobío NATURAL SCIENCES             NaN
# ENGINEERING, ELECTRICAL & ELECTRONIC Biobío ENGINEERING AND TECHNOLOGY   NaN
# ...                                                                      ...
# ENGINEERING, MARINE                  Biobío ENGINEERING AND TECHNOLOGY   NaN
# ETHNIC STUDIES                       Biobío SOCIAL SCIENCES              NaN
# SOCIAL ISSUES                        Biobío SOCIAL SCIENCES              NaN
# PRIMARY HEALTH CARE                  Biobío MEDICAL AND HEALTH SCIENCES  NaN
# PSYCHOLOGY, BIOLOGICAL               Biobío SOCIAL SCIENCES              NaN
#
#                                                                               min  \
# Disciplina                           region OECD
ñuble  MEDICAL AND HEALTH SCIENCES  0.208069
# AGRICULTURAL ECONOMICS & POLICY Ñuble  AGRICULTURAL SCIENCES        0.208069
#
#                                                                          max
# Disciplina                      region OECD
# AGRONOMY                        Ñuble  AGRICULTURAL SCIENCES        3.727909
# AGRICULTURE, MULTIDISCIPLINARY  Ñuble  AGRICULTURAL SCIENCES        3.190397
# FOOD SCIENCE & TECHNOLOGY       Ñuble  ENGINEERING AND TECHNOLOGY   2.514171
# PLANT SCIENCES                  Ñuble  NATURAL SCIENCES             2.392797
# VETERINARY SCIENCES             Ñuble  AGRICULTURAL SCIENCES        1.629877
# ...                                                                      ...
# HUMANITIES, MULTIDISCIPLINARY   Ñuble  HUMANITIES                   0.208069
# HEMATOLOGY                      Ñuble  MEDICAL AND HEALTH SCIENCES  0.208069
# PLANNING & DEVELOPMENT          Ñuble  SOCIAL SCIENCES              0.208069
# HEALTH CARE SCIENCES & SERVICES Ñuble  MEDICAL AND HEALTH SCIENCES  0.208069
# AGRICULTURAL ECONOMICS & POLICY Ñuble  AGRICULTURAL SCIENCES        0.208069
#
# [163 rows x 8 columns]

# %%
sort_list = oecd_wos_mapping["WoS"].tolist()

#alt.data_transformers.disable_max_rows()

wos_oecd_pub100 = alt.Chart(datos_wos_aggmean).mark_bar(
).encode(
    y=alt.Y('Pub/100mil:Q',title="Pub/100mil"),
    x=alt.X('Disciplina:O',title="Disciplina",sort=sort_list),
    color=alt.Color('OECD',title=""),
    #column=alt.Column('region:O'),
    ).properties( width=2000,
    height=300).facet(alt.Facet('region:O',title=""), columns=1,center=True).interactive()

#wos_oecd_pub100.save("wos_oecd_pub100.png",scale_factor=2.0)
wos_oecd_pub100
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ### instituciones

# %%
datos_inst.sort_values(by="# Publicaciones",ascending=False).head(20)
# Out:
#                   Institución  # Publicaciones  # Autores  % Hombre  % Mujer  \
# 20  Universidad de Concepción             1289       1862        65       35
# 18  Universidad de Concepción             1207       1544        65       35
# 24  Universidad de Concepción             1113       1424        65       35
# 22  Universidad de Concepción             1103       1449        65       35
# 25  Universidad de Concepción             1030       1267        66       34
# 27  Universidad de Concepción              885       1109        65       35
# 20  Universidad de Concepción              878       1113        64       36
# 23  Universidad de Concepción              854       1075        65       35
# 15  Universidad de Concepción              773        934        65       35
# 17  Universidad de Concepción              763        956        68       32
# 19  Universidad de Concepción              738        847        65       35
# 15  Universidad de Concepción              657        798        66       34
# 15  Universidad de Concepción              425        721        67       33
# 22       Universidad de Talca              421        487        74       26
# 26       Universidad de Talca              392        404        70       30
# 21       Universidad de Talca              369        420        76       24
# 28       Universidad de Talca              340        310        75       25
# 26       Universidad de Talca              327        349        70       30
# 29       Universidad de Talca              281        307        77       23
# 22    Universidad del Bío Bío              276        314        74       26
#
#     Producción Per Cápita   año
# 20                    0.7  2019
# 18                    0.8  2018
# 24                    0.8  2016
# 22                    0.8  2017
# 25                    0.8  2015
# 27                    0.8  2014
# 20                    0.8  2012
# 23                    0.8  2013
# 15                    0.8  2010
# 17                    0.8  2011
# 19                    0.9  2009
# 15                    0.8  2008
# 15                    0.6  2020
# 22                    0.9  2019
# 26                    1.0  2017
# 21                    0.9  2018
# 28                    1.1  2016
# 26                    0.9  2015
# 29                    0.9  2014
# 22                    0.9  2018

# %%
alt.Chart(datos_inst).mark_line(
    cornerRadiusTopLeft=3,
    cornerRadiusTopRight=3
).encode(
    y = alt.Y('# Publicaciones:Q'),
    x='año:O',
    color='Institución:N',
    #column='Nombre Región:N'
    
).properties( width=700,
    height=300)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Proyectos, universidades

# %%
hojas = ["F. REGULAR", "F. Iniciación","F.Postdoctorado","FONDAP","FONDEF","FONDEQUIP","FONIS","PIA"]

# %%
# 2014-2019
fregular = pd.read_excel("data/Estudio universidades 2014-2019.xlsx",sheet_name=hojas[0],skiprows=3,skipfooter=2).dropna(axis=1)
fregular.head()
# Out:
#    Años Acreditación en I+D+i  Institución  Postulados  Adjudicados  \
# 0                           7  U. de Chile        1850          652
# 1                           7          PUC        1497          628
# 2                           7         UdeC         822          241
# 3                           6      U.Talca         300          101
# 4                           6         UFRO         270           79
#
#    Tasa de Aprobación   tasas Univ Acreditadas 5, 6 y 7
# 0            0.352432                               0.29
# 1            0.419506                               0.29
# 2            0.293187                               0.29
# 3            0.336667                               0.29
# 4            0.292593                               0.29

# %%
fregularm = pd.melt(fregular,id_vars=['Institución'], value_vars = ['Postulados','Adjudicados'])


bar1 = alt.Chart(fregularm).mark_bar(
).encode(
    y = alt.Y('value:Q',title=""),
    x='Institución:O',
    color=alt.Color('variable',title=""),
    #column=alt.Column('variable'),
    order=alt.Order(
      # Sort the segments of the bars by this field
      'variable',
      sort='ascending'
    )
)


line = alt.Chart(fregular).mark_line(stroke="red"
).encode(
    y = alt.Y('Tasa de Aprobación:Q',axis=alt.Axis(title='Tasa de Aprobación', titleColor='red',grid=True)),
    x='Institución:O',    
)
final = alt.layer(bar1, line).resolve_scale(
    y = 'independent',
    #color="independent"
)
final
#final.save("fregular.svg",scale_factor=1.0)
# Out:
# alt.LayerChart(...)

# %%
pd.read_excel("data/Estudio universidades 2014-2019.xlsx")
# Out:
#     Unnamed: 0                     Unnamed: 1     Unnamed: 2  Unnamed: 3  \
# 0          NaN  FONDECYT REGULAR 2014 al 2019            NaN         NaN
# 1          NaN                            NaN            NaN         NaN
# 2          NaN     Años Acreditación en I+D+i    Institución  Postulados
# 3          NaN                              7    U. de Chile        1850
# 4          NaN                              7            PUC        1497
# 5          NaN                              7           UdeC         822
# 6          NaN                              6        U.Talca         300
# 7          NaN                              6           UFRO         270
# 8          NaN                              6        P.U.C.V         525
# 9          NaN                              6      U.C Norte         198
# 10         NaN                              6        Austral         405
# 11         NaN                              6          USACH         598
# 12         NaN                              6      U.T.F.S.M         308
# 13         NaN                              5     U.C.Temuco         122
# 14         NaN                              5  U.Antofagasta          94
# 15         NaN                              5    U.Adolfo I.         224
# 16         NaN                              5           UNAB         304
# 17         NaN                              5       U. Andes         189
# 18         NaN                              5            UTA         139
# 19         NaN                              5            UDP         235
# 20         NaN                              5        U.VALPO         258
# 21         NaN                              5            UDD         110
# 22         NaN                              5            UBB         234
# 23         NaN                            NaN            NaN         NaN
# 24         NaN                            NaN          TOTAL        8682
#
#      Unnamed: 4          Unnamed: 5                         Unnamed: 6
# 0           NaN                 NaN                                NaN
# 1           NaN                 NaN                                NaN
# 2   Adjudicados  Tasa de Aprobación   tasas Univ Acreditadas 5, 6 y 7
# 3           652            0.352432                               0.29
# 4           628            0.419506                               0.29
# 5           241            0.293187                               0.29
# 6           101            0.336667                               0.29
# 7            79            0.292593                               0.29
# 8           175            0.333333                               0.29
# 9            44            0.222222                               0.29
# 10          134            0.330864                               0.29
# 11          169            0.282609                               0.29
# 12          114             0.37013                               0.29
# 13           26            0.213115                               0.29
# 14           14            0.148936                               0.29
# 15           59            0.263393                               0.29
# 16          110            0.361842                               0.29
# 17           59            0.312169                               0.29
# 18           36            0.258993                               0.29
# 19           88            0.374468                               0.29
# 20           68            0.263566                               0.29
# 21           29            0.263636                               0.29
# 22           48            0.205128                               0.29
# 23          NaN            0.294939                                NaN
# 24         2874             0.33103                                NaN

# %%
finiciacion = pd.read_excel("data/Estudio universidades 2014-2019.xlsx",sheet_name=hojas[1],skiprows=4,skipfooter=2).dropna(axis=1)
finiciacion
# Out:
#     Años Acreditación en I+D+i    Institución  Postulados  Adjudicados  \
# 0                            7    U. de Chile         590          206
# 1                            7            PUC         548          215
# 2                            7           UdeC         305           89
# 3                            6        U.Talca         140           43
# 4                            6           UFRO         206           68
# 5                            6        P.U.C.V         298           79
# 6                            6      U.C Norte         130           24
# 7                            6        Austral         198           55
# 8                            6          USACH         261           69
# 9                            6      U.T.F.S.M         158           46
# 10                           5     U.C.Temuco         111           26
# 11                           5  U.Antofagasta          65           13
# 12                           5    U.Adolfo I.         137           40
# 13                           5           UNAB         177           56
# 14                           5       U. Andes         102           38
# 15                           5            UTA          72           16
# 16                           5            UDP         106           30
# 17                           5        U.VALPO         130           44
# 18                           5            UDD          92           20
# 19                           5            UBB         104           24
#
#     Tasa de Aprobación  X tasas Univ Acreditadas 5, 6 y 7
# 0             0.349153                               0.28
# 1             0.392336                               0.28
# 2             0.291803                               0.28
# 3             0.307143                               0.28
# 4             0.330097                               0.28
# 5             0.265101                               0.28
# 6             0.184615                               0.28
# 7             0.277778                               0.28
# 8             0.264368                               0.28
# 9             0.291139                               0.28
# 10            0.234234                               0.28
# 11            0.200000                               0.28
# 12            0.291971                               0.28
# 13            0.316384                               0.28
# 14            0.372549                               0.28
# 15            0.222222                               0.28
# 16            0.283019                               0.28
# 17            0.338462                               0.28
# 18            0.217391                               0.28
# 19            0.230769                               0.28

# %%
finiciacionm = pd.melt(finiciacion,id_vars=['Institución'], value_vars = ['Postulados','Adjudicados'])


bar1 = alt.Chart(finiciacionm).mark_bar(
).encode(
    y = alt.Y('value:Q',title=""),
    x='Institución:O',
    color=alt.Color('variable',title=""),
    #column=alt.Column('variable'),
    order=alt.Order(
      # Sort the segments of the bars by this field
      'variable',
      sort='ascending'
    )
)


line = alt.Chart(finiciacion).mark_line(stroke="red"
).encode(
    y = alt.Y('Tasa de Aprobación:Q',axis=alt.Axis(title='Tasa de Aprobación', titleColor='red',grid=True)),
    x='Institución:O',    
)
final = alt.layer(bar1, line).resolve_scale(
    y = 'independent',
    #color="independent"
)
final
# Out:
# alt.LayerChart(...)
