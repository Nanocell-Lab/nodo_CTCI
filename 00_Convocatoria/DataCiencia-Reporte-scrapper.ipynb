# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Requiere :
# - beautifulsoup4
# - lxml
# - html5lib
# - requests

# %%
# problemente esto requiera cambio, depeniendo del navegador y sistema operativo, no estoy seguro.

raw_header = """Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
Accept-Encoding: gzip, deflate, br
Accept-Language: en-US,en;q=0.9,es;q=0.8
Cache-Control: no-cache
Connection: keep-alive
Cookie: BIGipServerservidor_dataciencia-redsearch=1124073482.47873.0000; _fermenter_session=QLlwkl8dg1RtbNzeX9jvhA6b5KbX9bL9a2C64tbWetCgOQlNhT0tEFyShAc69VSzEcxLW5P1uUnmP8Al0SAxAzdkexQXMnvu4wHmg6wKt9T1z8wHj7gi4i%2BzjehTwRajuSnT%2Fl%2FeukwWmwsUK%2Bc%3D--xT3XX2NX2p5wuljw--%2BiAX4Q362CUT0eXxomct6g%3D%3D
Host: dataciencia.anid.cl
Pragma: no-cache
Referer: https://dataciencia.anid.cl/national/report
sec-ch-ua: "Chromium";v="94", "Google Chrome";v="94", ";Not A Brand";v="99"
sec-ch-ua-mobile: ?0
sec-ch-ua-platform: "Windows"
Sec-Fetch-Dest: document
Sec-Fetch-Mode: navigate
Sec-Fetch-Site: same-origin
Sec-Fetch-User: ?1
Upgrade-Insecure-Requests: 1
User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"""

# %%
headers_raw = {}
[headers_raw.update({header.split(":")[0]:header.split(":")[-1].strip()}) for header in raw_header.split("\n")];

# %%
json_headers = json.dumps(headers_raw,indent=4)
json_headers
# Out:
# '{\n    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",\n    "Accept-Encoding": "gzip, deflate, br",\n    "Accept-Language": "en-US,en;q=0.9,es;q=0.8",\n    "Cache-Control": "no-cache",\n    "Connection": "keep-alive",\n    "Cookie": "BIGipServerservidor_dataciencia-redsearch=1124073482.47873.0000; _fermenter_session=QLlwkl8dg1RtbNzeX9jvhA6b5KbX9bL9a2C64tbWetCgOQlNhT0tEFyShAc69VSzEcxLW5P1uUnmP8Al0SAxAzdkexQXMnvu4wHmg6wKt9T1z8wHj7gi4i%2BzjehTwRajuSnT%2Fl%2FeukwWmwsUK%2Bc%3D--xT3XX2NX2p5wuljw--%2BiAX4Q362CUT0eXxomct6g%3D%3D",\n    "Host": "dataciencia.anid.cl",\n    "Pragma": "no-cache",\n    "Referer": "//dataciencia.anid.cl/national/report",\n    "sec-ch-ua": "\\"Chromium\\";v=\\"94\\", \\"Google Chrome\\";v=\\"94\\", \\";Not A Brand\\";v=\\"99\\"",\n    "sec-ch-ua-mobile": "?0",\n    "sec-ch-ua-platform": "\\"Windows\\"",\n    "Sec-Fetch-Dest": "document",\n    "Sec-Fetch-Mode": "nav
# ...

# %% [markdown]
# ## Generar POST , con data, el token y los headers
# ### TODO - ver como generar tokens, posiblemente expiren,no lo se. si no funciona hay que sacar otro del navegaor con la herramienta de inspeccion.

# %%
### 'BioBío', 'Ñuble', 'Maule','OHiggins', [8,9,10,16]

# regions[]: 8
# regions[]: 9
# regions[]: 10
# regions[]: 16
# from-year: 2008
# to-year: 2020
# commit: Generar

# %%
url = 'https://dataciencia.anid.cl/national/report'


token = "l4a9iJzyc+y16kdAygUL2QD7sRbR5vI7JtPx1Q6O2OPqJokG7M3yB1J3CiYsRJxx9tbc7VUaipYoTZnCW6CdMQ=="
dict_data = {"authenticity_token":token,
             "regions[]":["8","9","10","16"],
             "commit":"Generar",
             "from-year":"2008",
             "to-year":"2020"
            }

# %%
r = requests.post(url,headers=headers_raw,data=dict_data)
print(r)
# Out:
# <Response [200]>

# %%
### Con GET se parsea todo, no disgregado por regiones

# url = 'https://dataciencia.anid.cl/panorama/report'

# r = requests.get(url)
# print(r)
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<html>\n  <head>\n    <title>Dataciencia - ANID</title>\n    <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="KUhOY1XvYDFUSF9wjXOs1hMDR0neajms++/BBWlyvoNU6HrtJdDh2rPVEhZrMjt+5S4qslqWQQH1cakSPFz7UQ==" />\n    <meta name="csp-nonce" />\n\n    <link rel="stylesheet" media="screen" href="/assets/application-3c0e426cac54301f5cb2e17433b087156d4375395722aac8c31c8f17b2168f77.css" />\n    \n    <!-- END: CSS -->\n    <script src="/assets/application-d8eeeac6c13ddc0b717fbb8e5dc6d29f6421819843d6cca1b31f4a69736ba855.js" data-turbolinks-track="reload"></script>\n    \n    <!-- END: JS -->\n  </head>\n  <body>\n    <div id="left-bar" class="left-bar step-dimension">\n      <div id="vertical-text-container" class="vertical-text-container">\n        <p class="vertical-text">\n          <b id="section-name" class="has-text-white vtc-dimension is-size-4">\n            Colección SciELO Chile\n          </b>\n        </p>\n      </div>\n    </di
# ...

# %%
soup = BeautifulSoup(r.text,"html.parser")

tables = soup.find_all("table",class_="table")

# %%
tables
# Out:
# [<table class="table" id="r-table">
#  <thead>
#  <tr>
#  <th>Región</th>
#  <th>#Publicaciones</th>
#  <th>#Autores</th>
#  <th>%Hombre</th>
#  <th>%Mujer</th>
#  <th>Produccíon Per Cápida</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td><a class="a-style-1" href="/region/8">Región del Libertador General Bernardo O'Higgins</a></td>
#  <td>851</td>
#  <td>876</td>
#  <td>55.5</td>
#  <td>22.6</td>
#  <td>1.0</td>
#  </tr>
#  <tr>
#  <td><a class="a-style-1" href="/region/9">Región del Maule</a></td>
#  <td>8658</td>
#  <td>8769</td>
#  <td>56.9</td>
#  <td>25.2</td>
#  <td>1.0</td>
#  </tr>
#  <tr>
#  <td><a class="a-style-1" href="/region/10">Región del Biobío</a></td>
#  <td>24204</td>
#  <td>25120</td>
#  <td>50.6</td>
#  <td>30.6</td>
#  <td>1.0</td>
#  </tr>
#  <tr>
#  <td><a class="a-style-1" href="/region/16">Región Ñuble</a></td>
#  <td>2764</td>
#  <td>2856</td>
#  <td>49.4</td>
#  <td>32.0</td>
#  <td>1.0</td>
#  </tr>
#  </tbody>
#  </table>,
# ...

# %%
table_names = ["Disciplina OECD","Disciplina WoS","Institución","Región"]
datos_pd = {}
for i,t in enumerate(tables):
    pd_table = pd.read_html(t.prettify())[0]
    datos_pd[table_names[i]] = pd_table

# %%
datos_pd["Disciplina OECD"]
# Out:
#                                              Región  #Publicaciones  #Autores  \
# 0  Región del Libertador General Bernardo O'Higgins             851       876
# 1                                  Región del Maule            8658      8769
# 2                                 Región del Biobío           24204     25120
# 3                                      Región Ñuble            2764      2856
#
#    %Hombre  %Mujer  Produccíon Per Cápida
# 0     55.5    22.6                    1.0
# 1     56.9    25.2                    1.0
# 2     50.6    30.6                    1.0
# 3     49.4    32.0                    1.0

# %% [markdown]
# ## test iterativo

# %%
import time

# %%
años = [str(x) for x in range(2008,2022)]
regiones = [str(x) for x in range(1,17)]

# %%
regionSur=["8","9","10","16"]

# %%
y+"_"+reg
# Out:
# '2021_16'

# %%
años
# Out:
# ['2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %%
datos_años_region = {}
for y in años:
    for reg in regionSur:
        
        print("request año",y)
        print("request region",reg)
        dict_data.update({"from-year":y,"to-year":y,"regions[]":reg})

        r = requests.post(url,headers=headers_raw,data=dict_data)
        print("request completed",r.status_code)
        time.sleep(5)
        print("5 sec ready")
        soup = BeautifulSoup(r.text,"html.parser")
        tables = soup.find_all("table",class_="table")

        table_names = ["Disciplina OECD","Disciplina WoS","Institución","Región"]
        datos_pd = {}
        for i,t in enumerate(tables):
            pd_table = pd.read_html(t.prettify())[0]

            #add tag año
            pd_table["año"] = y
            pd_table["region"] = reg
            datos_pd[table_names[i]] = pd_table

        datos_años_region[y+"_"+reg] = datos_pd
# Out:
# request año 2008
# request region 8
# request completed 200
# 5 sec ready
# request año 2008
# request region 9
# request completed 200
# 5 sec ready
# request año 2008
# request region 10
# request completed 200
# 5 sec ready
# request año 2008
# request region 16
# request completed 200
# 5 sec ready
# request año 2009
# request region 8
# request completed 200
# 5 sec ready
# request año 2009
# request region 9
# request completed 200
# 5 sec ready
# request año 2009
# request region 10
# request completed 200
# 5 sec ready
# request año 2009
# request region 16
# request completed 200
# 5 sec ready
# request año 2010
# request region 8
# request completed 200
# 5 sec ready
# request año 2010
# request region 9
# request completed 200
# 5 sec ready
# request año 2010
# request region 10
# request completed 200
# 5 sec ready
# request año 2010
# request region 16
# request completed 200
# 5 sec ready
# request año 2011
# request region 8
# request completed 200
# 5 sec ready
# ...

# %%
# 'BioBío', 'Ñuble', 'Maule','OHiggins', [8,9,10,16]

# %%
map_region = {"16":"Ñuble","8":"O'Higgins","9":"Maule",
             "10":"Biobío"}

# %%
datos_region = []
datos_oecd = []
datos_wos = []
datos_inst = []
for a,d in datos_años_region.items():
    d["Región"]["region"] = d["Región"]["region"].map(map_region)
    d["Disciplina OECD"]["region"] = d["Disciplina OECD"]["region"].map(map_region)
    d["Disciplina WoS"]["region"] = d["Disciplina WoS"]["region"].map(map_region)
    d["Institución"]["region"] = d["Institución"]["region"].map(map_region)
    
    datos_region.append(d["Región"])
    datos_oecd.append(d["Disciplina OECD"])
    datos_wos.append(d["Disciplina WoS"])
    datos_inst.append(d["Institución"])

# %%
# TODO - fix this something mess up order
datos_oecd_conc = pd.concat(datos_wos)
datos_wos_conc = pd.concat(datos_inst)
datos_region_conc = pd.concat(datos_oecd)
datos_inst_conc = pd.concat(datos_region)

# %%
datos_inst_conc
# Out:
#                                           Institución  #Publicaciones  \
# 0                            Universidad de O`Higgins             366
# 1                            Universidad de O’Higgins             361
# 2                      Corporación Nacional del Cobre              93
# 3        Centro de Estudios Avanzados en Fruticultura              53
# 4          Instituto de Investigaciones Agropecuarias              48
# ..                                                ...             ...
# 4                    Hospital Clínico Herminda Martin              49
# 5   Group of Research and Innovation in Vascular H...              24
# 6             Grp Res & Innovat Vasc Hlth GRIVAS Hlth              22
# 7     Instituto de Investigaciones Agropecuarias INIA              14
# 8                           Hosp Clin Herminda Martin              13
#
#     #Autores  %Hombre  %Mujer  Produccíon Per Cápida   año     region
# ...

# %%
datos_region_conc.to_csv("../data/DataCiencia_reporteRegion_sur.v3.csv")
datos_oecd_conc.to_csv("../data/DataCiencia_reporteOECD_sur.v3.csv")
datos_wos_conc.to_csv("../data/DataCiencia_reporteWoS_sur.v3.csv")
datos_inst_conc.to_csv("../data/DataCiencia_reporteInst_sur.v3.csv")
